# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
price=pd.read_csv('train[1].csv')
price.head()
# Out:
#    Battery_Power  Clock_Speed  FC  Int_Memory  Mobile_D  Mobile_W  Cores  PC  \
# 0            842          2.2   1           7       0.6       188      2   2
# 1           1021          0.5   0          53       0.7       136      3   6
# 2            563          0.5   2          41       0.9       145      5   6
# 3            615          2.5   0          10       0.8       131      6   9
# 4           1821          1.2  13          44       0.6       141      2  14
#
#    Pixel_H  Pixel_W  ...  Screen_H  Screen_W  Talk_Time  Four_G  Three_G  \
# 0       20      756  ...         9         7         19       0        0
# 1      905     1988  ...        17         3          7       1        1
# 2     1263     1716  ...        11         2          9       1        1
# 3     1216     1786  ...        16         8         11       0        1
# 4     1208     1212  ...         8         2         15       1        1
#
#    Touch_Screen  Dual_SIM  Bluetooth  WiFi  Price_Range
# ...

# %%
price.tail()
# Out:
#       Battery_Power  Clock_Speed  FC  Int_Memory  Mobile_D  Mobile_W  Cores  \
# 1995            794          0.5   0           2       0.8       106      6
# 1996           1965          2.6   0          39       0.2       187      4
# 1997           1911          0.9   1          36       0.7       108      8
# 1998           1512          0.9   4          46       0.1       145      5
# 1999            510          2.0   5          45       0.9       168      6
#
#       PC  Pixel_H  Pixel_W  ...  Screen_H  Screen_W  Talk_Time  Four_G  \
# 1995  14     1222     1890  ...        13         4         19       1
# 1996   3      915     1965  ...        11        10         16       0
# 1997   3      868     1632  ...         9         1          5       1
# 1998   5      336      670  ...        18        10         19       1
# 1999  16      483      754  ...        19         4          2       1
#
#       Three_G  Touch_Screen  Dual_SIM  Bluetooth  WiFi  Price_Range
# ...

# %%
price.dtypes
# Out:
# Battery_Power      int64
# Clock_Speed      float64
# FC                 int64
# Int_Memory         int64
# Mobile_D         float64
# Mobile_W           int64
# Cores              int64
# PC                 int64
# Pixel_H            int64
# Pixel_W            int64
# Ram                int64
# Screen_H           int64
# Screen_W           int64
# Talk_Time          int64
# Four_G             int64
# Three_G            int64
# Touch_Screen       int64
# Dual_SIM           int64
# Bluetooth          int64
# WiFi               int64
# Price_Range        int64
# dtype: object

# %%
price.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Battery_Power  2000 non-null   int64
#  1   Clock_Speed    2000 non-null   float64
#  2   FC             2000 non-null   int64
#  3   Int_Memory     2000 non-null   int64
#  4   Mobile_D       2000 non-null   float64
#  5   Mobile_W       2000 non-null   int64
#  6   Cores          2000 non-null   int64
#  7   PC             2000 non-null   int64
#  8   Pixel_H        2000 non-null   int64
#  9   Pixel_W        2000 non-null   int64
#  10  Ram            2000 non-null   int64
#  11  Screen_H       2000 non-null   int64
#  12  Screen_W       2000 non-null   int64
#  13  Talk_Time      2000 non-null   int64
#  14  Four_G         2000 non-null   int64
#  15  Three_G        2000 non-null   int64
#  16  Touch_Screen   2000 non-null   int64
#  17  Dual_SIM       2000 non-null   int64
# ...

# %%
price.columns
# Out:
# Index(['Battery_Power', 'Clock_Speed', 'FC', 'Int_Memory', 'Mobile_D',
#        'Mobile_W', 'Cores', 'PC', 'Pixel_H', 'Pixel_W', 'Ram', 'Screen_H',
#        'Screen_W', 'Talk_Time', 'Four_G', 'Three_G', 'Touch_Screen',
#        'Dual_SIM', 'Bluetooth', 'WiFi', 'Price_Range'],
#       dtype='object')

# %%
price.shape
# Out:
# (2000, 21)

# %%
price.isna().sum() #price.isnull().sum()
# Out:
# Battery_Power    0
# Clock_Speed      0
# FC               0
# Int_Memory       0
# Mobile_D         0
# Mobile_W         0
# Cores            0
# PC               0
# Pixel_H          0
# Pixel_W          0
# Ram              0
# Screen_H         0
# Screen_W         0
# Talk_Time        0
# Four_G           0
# Three_G          0
# Touch_Screen     0
# Dual_SIM         0
# Bluetooth        0
# WiFi             0
# Price_Range      0
# dtype: int64

# %%
price.describe()
# Out:
#        Battery_Power  Clock_Speed           FC   Int_Memory     Mobile_D  \
# count    2000.000000  2000.000000  2000.000000  2000.000000  2000.000000
# mean     1238.518500     1.522250     4.309500    32.046500     0.501750
# std       439.418206     0.816004     4.341444    18.145715     0.288416
# min       501.000000     0.500000     0.000000     2.000000     0.100000
# 25%       851.750000     0.700000     1.000000    16.000000     0.200000
# 50%      1226.000000     1.500000     3.000000    32.000000     0.500000
# 75%      1615.250000     2.200000     7.000000    48.000000     0.800000
# max      1998.000000     3.000000    19.000000    64.000000     1.000000
#
#           Mobile_W        Cores           PC      Pixel_H      Pixel_W  ...  \
# count  2000.000000  2000.000000  2000.000000  2000.000000  2000.000000  ...
# mean    140.249000     4.520500     9.916500   645.108000  1251.515500  ...
# std      35.399655     2.287837     6.064315   443.780811   432.199447  ...
# ...

# %%
price.describe(include='all')
# Out:
#        Battery_Power  Clock_Speed           FC   Int_Memory     Mobile_D  \
# count    2000.000000  2000.000000  2000.000000  2000.000000  2000.000000
# mean     1238.518500     1.522250     4.309500    32.046500     0.501750
# std       439.418206     0.816004     4.341444    18.145715     0.288416
# min       501.000000     0.500000     0.000000     2.000000     0.100000
# 25%       851.750000     0.700000     1.000000    16.000000     0.200000
# 50%      1226.000000     1.500000     3.000000    32.000000     0.500000
# 75%      1615.250000     2.200000     7.000000    48.000000     0.800000
# max      1998.000000     3.000000    19.000000    64.000000     1.000000
#
#           Mobile_W        Cores           PC      Pixel_H      Pixel_W  ...  \
# count  2000.000000  2000.000000  2000.000000  2000.000000  2000.000000  ...
# mean    140.249000     4.520500     9.916500   645.108000  1251.515500  ...
# std      35.399655     2.287837     6.064315   443.780811   432.199447  ...
# ...

# %%
price.mean()
price.median()
price.mode()

# %%
price.head()
# Out:
#    Battery_Power  Clock_Speed  FC  Int_Memory  Mobile_D  Mobile_W  Cores  PC  \
# 0            842          2.2   1           7       0.6       188      2   2
# 1           1021          0.5   0          53       0.7       136      3   6
# 2            563          0.5   2          41       0.9       145      5   6
# 3            615          2.5   0          10       0.8       131      6   9
# 4           1821          1.2  13          44       0.6       141      2  14
#
#    Pixel_H  Pixel_W  ...  Screen_H  Screen_W  Talk_Time  Four_G  Three_G  \
# 0       20      756  ...         9         7         19       0        0
# 1      905     1988  ...        17         3          7       1        1
# 2     1263     1716  ...        11         2          9       1        1
# 3     1216     1786  ...        16         8         11       0        1
# 4     1208     1212  ...         8         2         15       1        1
#
#    Touch_Screen  Dual_SIM  Bluetooth  WiFi  Price_Range
# ...

# %%
plt.scatter(x=price['Price_Range'],y=price['Ram'])

# %%
plt.scatter(x=price['Price_Range'],y=price['Battery_Power'])

# %%
plt.scatter(x=price['Price_Range'],y=price['FC'])

# %%
pip install seaborn

# %%
import seaborn as sns

# %%
sns.jointplot(x='Ram',y='Price_Range',data=price,color='red',kind='kde');

# %%
sns.pointplot(y="Int_Memory", x="Price_Range", data=price)
# Out:
# <Axes: xlabel='Price_Range', ylabel='Int_Memory'>

# %%
plt.boxplot(price)
plt.show()

# %% [markdown]
# # % of 3g users which supprots the phone

# %%
labels = ["3G-supported",'Not supported']
values=price['Three_G'].value_counts().values

# %%
fig1, ax1 = plt.subplots()
ax1.pie(values, labels=labels, autopct='%1.1f%%',shadow=True,startangle=90)
plt.show()

# %% [markdown]
# #  % of Phones which support 4G

# %%
labels4g = ["4G-supported",'Not supported']
values4g = price['Four_G'].value_counts().values

# %%
fig1, ax1 = plt.subplots()
ax1.pie(values4g, labels=labels4g, autopct='%1.1f%%',shadow=True,startangle=90)
plt.show()

# %%
# battery power vs battery range
sns.boxplot(x="Price_Range", y="Battery_Power", data=price)
# Out:
# <Axes: xlabel='Price_Range', ylabel='Battery_Power'>

# %%
# mobile price vs mobile wegiht
sns.jointplot(x='Mobile_W',y='Price_Range',kind='kde',data=price,);

# %% [markdown]
# training the dataset or preparing x and y

# %%
y=price['Price_Range']

# %%
y
# Out:
# 0       1
# 1       2
# 2       2
# 3       2
# 4       1
#        ..
# 1995    0
# 1996    2
# 1997    3
# 1998    0
# 1999    3
# Name: Price_Range, Length: 2000, dtype: int64

# %%
x=price.drop('Price_Range',axis=1)

# %%
x
# Out:
#       Battery_Power  Clock_Speed  FC  Int_Memory  Mobile_D  Mobile_W  Cores  \
# 0               842          2.2   1           7       0.6       188      2
# 1              1021          0.5   0          53       0.7       136      3
# 2               563          0.5   2          41       0.9       145      5
# 3               615          2.5   0          10       0.8       131      6
# 4              1821          1.2  13          44       0.6       141      2
# ...             ...          ...  ..         ...       ...       ...    ...
# 1995            794          0.5   0           2       0.8       106      6
# 1996           1965          2.6   0          39       0.2       187      4
# 1997           1911          0.9   1          36       0.7       108      8
# 1998           1512          0.9   4          46       0.1       145      5
# 1999            510          2.0   5          45       0.9       168      6
#
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier

# %%
X_train,X_test,Y_train,Y_test=train_test_split(x,y,train_size=0.75,random_state=0)

# %%
X_train.shape
# Out:
# (1500, 20)

# %%
X_test.shape
# Out:
# (500, 20)

# %%
Y_train.shape
# Out:
# (1500,)

# %%
Y_test.shape
# Out:
# (500,)

# %% [markdown]
# Linear Regression algorthim used

# %%
model=LinearRegression()

# %%
model.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
model.score(X_train,Y_train)
# Out:
# 0.9170426046312816

# %%
Y_pred=model.predict(X_test)
Y_pred
# Out:
# array([ 2.72163139e+00, -1.92448477e-01,  1.77872837e+00,  1.53130494e+00,
#         2.36998336e+00, -3.40857658e-01, -1.32701256e-01,  2.48629381e+00,
#         2.78125246e+00,  1.13590077e+00,  6.20834513e-01,  2.75341063e+00,
#         3.17322371e-01,  1.80311445e+00,  2.93228967e+00,  2.40077665e-01,
#         3.42768939e+00,  1.74863906e+00,  1.79291781e+00,  8.48293396e-01,
#         2.62366786e-01,  2.56872820e-01,  3.28243817e+00,  9.65593527e-01,
#         1.57394287e+00,  1.69356196e+00,  3.74749749e+00,  1.11900444e+00,
#         3.34759287e+00,  1.17704391e+00,  1.35933245e+00,  2.87768704e-01,
#         1.61014492e+00,  5.11006513e-01,  1.53722576e+00,  3.35557271e+00,
#        -5.95395950e-01, -7.83054718e-02,  3.08277252e+00,  3.23564562e+00,
#         2.38055727e+00,  1.33329436e+00,  2.94773654e+00,  2.51356802e+00,
#         1.20581568e+00,  3.45854690e+00, -3.14260115e-01,  1.19276707e+00,
# ...

# %%
from sklearn.metrics import mean_absolute_error, mean_absolute_percentage_error, mean_squared_error

# %%
print(mean_absolute_error(Y_test,Y_pred))
print(mean_absolute_percentage_error(Y_test,Y_pred))
print(mean_squared_error(Y_test,Y_pred))
# Out:
# 0.2747606739866767
# 310550246027776.6
# 0.10248318249564935

# %% [markdown]
# Logistic regression model

# %%
model_lr = LogisticRegression(multi_class = 'multinomial', solver = 'sag',  max_iter = 10000)

# %%
model_lr.fit(X_train,Y_train)
# Out:
# LogisticRegression(max_iter=10000, multi_class='multinomial', solver='sag')

# %%
model_lr.intercept_
# Out:
# array([ 0.01903349,  0.0055874 , -0.00222169, -0.0223992 ])

# %%
model_lr.coef_
# Out:
# array([[-1.45162663e-03,  3.68395773e-02,  1.03083167e-03,
#          2.63362357e-02,  7.63466768e-03,  3.96130257e-02,
#          8.99424301e-02,  6.58887574e-02, -1.87091177e-03,
#          3.09472847e-04, -4.98277683e-03,  1.48380570e-01,
#          3.86482693e-02,  9.16746794e-02,  9.04261771e-03,
#          1.11345164e-02,  1.34564921e-02,  9.44474625e-03,
#          8.27452976e-03,  1.01315805e-02],
#        [ 4.49818598e-06,  4.63531123e-03,  1.48490718e-02,
#          9.14122942e-03,  5.37956966e-03,  1.19192073e-02,
#         -2.32377984e-02,  1.40286897e-02, -3.26368728e-04,
#          2.79299052e-04, -7.89045717e-04,  3.99102282e-02,
#         -3.21593995e-03,  3.95630145e-02,  6.84761402e-03,
#          6.68263503e-03,  4.49782508e-03,  8.35278118e-03,
#          2.25940644e-03,  3.06756267e-03],
#        [ 4.59707092e-04, -8.47549191e-03,  5.55358311e-03,
#         -1.27447412e-02, -4.87342866e-03, -9.44709571e-03,
# ...

# %%
Y_pred=model_lr.predict(X_test)
Y_pred
# Out:
# array([3, 0, 2, 1, 3, 0, 0, 2, 3, 1, 1, 3, 1, 2, 3, 0, 3, 2, 2, 1, 0, 0,
#        3, 1, 1, 3, 3, 1, 3, 1, 2, 0, 2, 1, 2, 3, 0, 0, 3, 2, 2, 2, 3, 3,
#        2, 3, 0, 1, 3, 2, 1, 2, 0, 3, 0, 3, 3, 1, 0, 3, 3, 1, 2, 1, 1, 3,
#        3, 3, 2, 2, 3, 3, 1, 0, 1, 3, 3, 2, 1, 1, 3, 1, 3, 0, 0, 0, 2, 1,
#        1, 3, 1, 2, 2, 0, 0, 3, 2, 3, 0, 2, 1, 2, 2, 1, 3, 3, 3, 2, 2, 3,
#        2, 0, 0, 2, 2, 3, 0, 1, 0, 0, 0, 3, 2, 2, 1, 2, 1, 0, 0, 3, 1, 3,
#        3, 2, 3, 3, 3, 3, 0, 1, 1, 2, 1, 3, 0, 3, 0, 0, 2, 0, 1, 1, 1, 1,
#        3, 0, 0, 3, 1, 3, 2, 2, 2, 1, 3, 3, 3, 3, 1, 0, 3, 2, 1, 3, 3, 0,
#        1, 2, 3, 1, 3, 1, 0, 1, 2, 1, 2, 0, 3, 3, 1, 2, 0, 2, 2, 1, 1, 3,
#        2, 0, 3, 3, 3, 0, 1, 3, 2, 2, 0, 0, 0, 1, 2, 2, 0, 0, 0, 3, 2, 2,
#        3, 3, 0, 0, 3, 3, 2, 2, 0, 2, 0, 0, 0, 3, 2, 0, 2, 3, 0, 1, 0, 2,
#        3, 2, 0, 0, 1, 3, 3, 2, 2, 0, 3, 1, 1, 0, 2, 2, 3, 2, 0, 0, 1, 3,
#        2, 2, 2, 3, 3, 2, 1, 2, 2, 2, 1, 3, 2, 2, 2, 1, 0, 1, 1, 0, 0, 0,
# ...

# %%
from sklearn.metrics import confusion_matrix,accuracy_score,classification_report

# %%
logistic=accuracy_score(Y_test,Y_pred)
print(confusion_matrix(Y_test,Y_pred))
print(classification_report(Y_test,Y_pred))
logistic
# Out:
# [[108  15   1   0]
#  [ 11  76  22   1]
#  [  0  24  69  32]
#  [  0   1  36 104]]
#               precision    recall  f1-score   support
#
#            0       0.91      0.87      0.89       124
#            1       0.66      0.69      0.67       110
#            2       0.54      0.55      0.55       125
#            3       0.76      0.74      0.75       141
#
#     accuracy                           0.71       500
#    macro avg       0.72      0.71      0.71       500
# weighted avg       0.72      0.71      0.72       500
# 0.714

# %% [markdown]
# KNN neigbohr model is used here

# %%
model_knn=KNeighborsClassifier(n_neighbors=3)

# %%
model_knn=model_knn.fit(X_train,Y_train)

# %%
Y_pred=model_knn.predict(X_test)
Y_pred
# Out:
# array([3, 0, 2, 2, 3, 0, 0, 2, 3, 1, 1, 3, 0, 2, 3, 0, 3, 2, 2, 1, 0, 0,
#        3, 1, 1, 2, 3, 1, 3, 1, 1, 0, 2, 0, 2, 3, 0, 0, 3, 3, 2, 1, 3, 3,
#        1, 3, 0, 1, 3, 1, 1, 3, 0, 3, 0, 3, 2, 2, 0, 3, 3, 1, 3, 2, 1, 2,
#        3, 2, 1, 2, 3, 2, 1, 0, 1, 3, 2, 1, 1, 2, 3, 3, 3, 0, 0, 0, 2, 0,
#        2, 3, 1, 2, 3, 1, 0, 3, 3, 3, 0, 3, 1, 1, 3, 1, 3, 2, 2, 3, 2, 3,
#        3, 0, 0, 1, 3, 3, 0, 1, 1, 0, 0, 3, 2, 2, 1, 1, 1, 1, 0, 2, 1, 3,
#        2, 3, 3, 3, 3, 2, 0, 1, 1, 2, 1, 3, 0, 3, 0, 0, 2, 0, 1, 1, 1, 1,
#        3, 0, 0, 3, 1, 3, 2, 1, 3, 1, 2, 3, 3, 2, 1, 0, 3, 2, 2, 3, 3, 0,
#        2, 2, 3, 0, 2, 1, 0, 1, 3, 1, 2, 0, 2, 3, 1, 1, 0, 2, 3, 0, 1, 3,
#        2, 0, 3, 3, 2, 1, 2, 3, 3, 3, 0, 0, 0, 2, 3, 3, 0, 0, 1, 3, 1, 3,
#        3, 3, 0, 0, 2, 2, 3, 1, 0, 2, 0, 0, 0, 3, 3, 0, 2, 2, 1, 1, 0, 2,
#        3, 3, 0, 0, 1, 3, 3, 2, 3, 0, 3, 1, 1, 0, 2, 3, 3, 2, 0, 0, 1, 2,
#        3, 2, 2, 3, 1, 1, 0, 3, 3, 2, 1, 3, 3, 2, 2, 1, 0, 2, 2, 1, 0, 0,
# ...

# %%
from sklearn.metrics import classification_report,accuracy_score,f1_score,confusion_matrix

# %%
knn=accuracy_score(Y_pred,Y_test)
print(classification_report(Y_pred,Y_test))
print(confusion_matrix(Y_pred,Y_test))
knn
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.95      0.97       128
#            1       0.92      0.92      0.92       110
#            2       0.86      0.90      0.88       119
#            3       0.94      0.92      0.93       143
#
#     accuracy                           0.92       500
#    macro avg       0.92      0.92      0.92       500
# weighted avg       0.93      0.92      0.92       500
#
# [[122   6   0   0]
#  [  2 101   7   0]
#  [  0   3 107   9]
#  [  0   0  11 132]]
# 0.924

# %%
batterypower=int(input("enter the power of battery "))
clockspeed=float(input("enter the clock speed "))
fc=int(input("enter the value of FC "))
intmemory=int(input("intmemory "))
mobiled=float(input("mobiled "))
mobilew=int(input("mobilew "))
cores=int(input("enter the no of cores"))
pc=int(input("PC"))
pixelH=int(input("pixelH"))
pixelW=int(input("pixelW"))
ram=int(input("ram"))
screenH=int(input("screenH"))
screenW=int(input("screenw"))
talktime=int(input("talktime"))
fourg=int(input("4g"))
threeg=int(input("3g"))
touchscreen=int(input("touchscreen"))
dualsim=int(input("dualsim"))
bluetooth=int(input("bluetooth"))
wifi=int(input("wifi"))
ml={'Battery_Power':[batterypower],'Clock_Speed':[clockspeed],'FC':[fc],'Int_Memory':[intmemory],'Mobile_D':[mobiled],'Mobile_W':[mobilew],'Cores':[cores],'PC':[pc],'Pixel_H':[pixelH], 'Pixel_W':[pixelW], 'Ram':[ram], 'Screen_H':[screenH],
       'Screen_W':[screenW], 'Talk_Time':[talktime], 'Four_G':[fourg], 'Three_G':[threeg], 'Touch_Screen':[touchscreen],
       'Dual_SIM':[dualsim], 'Bluetooth':[bluetooth], 'WiFi':[wifi]}
df=pd.DataFrame(ml)
# Out:
# enter the power of battery 1000
# enter the clock speed 0.5
# enter the value of FC 1
# intmemory 1000
# mobiled 100
# mobilew 1000
# enter the no of cores5
# PC10
# pixelH100
# pixelW1000
# ram1000
# screenH100
# screenw100
# talktime10
# 4g1
# 3g1
# touchscreen1
# dualsim1
# bluetooth1
# wifi1

# %%
df
# Out:
#    Battery_Power  Clock_Speed  FC  Int_Memory  Mobile_D  Mobile_W  Cores  PC  \
# 0           1000          0.5   1        1000     100.0      1000      5  10
#
#    Pixel_H  Pixel_W   Ram  Screen_H  Screen_W  Talk_Time  Four_G  Three_G  \
# 0      100     1000  1000       100       100         10       1        1
#
#    Touch_Screen  Dual_SIM  Bluetooth  WiFi
# 0             1         1          1     1

# %%
predict_df=model_knn.predict(df)
predict_df
for i in predict_df:
  print(i)
# Out:
# 0

# %% [markdown]
# MOdel comparsion

# %%
import pandas as pd
results=pd.DataFrame({'Model':['LogisticRegression','KNeighbors'],
                    'Accuracy Score':[logistic,knn]})
result_df=results.sort_values(by='Accuracy Score', ascending=False)
result_df=result_df.set_index('Model')
result_df
# Out:
#                     Accuracy Score
# Model
# KNeighbors                   0.924
# LogisticRegression           0.714

# %%
plt.scatter(x='logistic',y='knn',color ='maroon')
